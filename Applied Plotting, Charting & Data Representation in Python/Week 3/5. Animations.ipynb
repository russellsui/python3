# %%
# %matplotlib notebook
import matplotlib.animation as animation
import numpy as np
import matplotlib.pyplot as plt
n = 100
# returns n normal values
x = np.random.randn(n)

def update(curr):
    
# first of all we need to check if curr == n,i.e. the process ends
    if curr == n:
        a.event_source.stop()
    plt.cla()
# create bins with some space between using arange
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins = bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the normal distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
# plt.annotate(text, a list [x,y] to specify the location)
    plt.annotate('n = {}'.format(curr), [3,27])
# Out:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 387, in process
#     proxy(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 227, in __call__
#     return mtd(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/animation.py", line 1499, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
fig = plt.figure()
# intervalis the 间隔时间 for each update
a = animation.FuncAnimation(fig,update, interval = 500)
# Out:
# <img src="data:image/png;base64,..." width="640">
