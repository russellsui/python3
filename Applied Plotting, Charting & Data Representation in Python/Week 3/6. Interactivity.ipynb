# %%
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
# random.rand gives random number between 0 and 1
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {}, {} {} and data {}, {}'.format(event.x,
                                                                           event,y,
                                                                          '\n',
                                                                          event.xdata,
                                                                          event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event',onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 7

# %%
from random import shuffle
import pandas as pd
origins = ['China','Brazil','India','USA','Canada','UK','Germany','Iraq','Chile','Mexico']
shuffle(origins)
df = pd.DataFrame({'height':np.random.rand(10),'country':origins,'weight':np.random.rand(10)})
df
# Out:
#      height  country    weight
# 0  0.461797       UK  0.982626
# 1  0.442721   Brazil  0.386799
# 2  0.898890    China  0.108990
# 3  0.314795    India  0.285250
# 4  0.964051   Canada  0.762894
# 5  0.460556     Iraq  0.918173
# 6  0.774815  Germany  0.506873
# 7  0.703332    Chile  0.651283
# 8  0.631042      USA  0.497910
# 9  0.471317   Mexico  0.403016

# %%
plt.figure()
plt.scatter(df['height'], df['weight'],picker =5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'Height')

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item came from {}'.format(origin))
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 8
