# %%
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# Out:
#   File "<ipython-input-2-6646f04d16e3>", line 9
#     x.get_ticklabels() = ['Python', 'SQL', 'Java', 'C++', 'JavaScript']
#                                                                        ^
# SyntaxError: can't assign to function call

# %%
# Exercise 1
plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# first plot the popularity bar chart, use align = center to make the center of the bars at the center of each label

# TODO: change the bar colors to be less bright blue
# first change the colors from blue to light grey
bars = plt.bar(pos, popularity, align='center', linewidth = 0.5, color='lightslategrey')
# actually could assign a value to the plt.bar, like a list, then use bar[i] to manage the 
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')


plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# TODO: remove all the ticks (both axes), and tick labels on the Y axis
# we use plt.tick_params or we could use plt.tick_params or ax.tick_params, set all the attribute off except for
# the bottom labels

plt.tick_params(top = 0, bottom = 0, left = 0, right = 0, labelleft = 0, labelbottom = 1)

# further, remove the frame of our plot

# first get the current axes of the figure
axes = plt.gca()
for spine in axes.spines.values():
    spine.set_visible(False)

# direct label each bar with Y axis values

# First we make a loop thru all the bars on the figure
# use axes.text to add text on each bar,
# axes.text(location of text in x, location of text in y, text content, alignment horizontally like ha = 'center'
# color, fontsize etc as kwargs
for bar in bars:
    axes.text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha = 'center', color='w', fontsize=11)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
