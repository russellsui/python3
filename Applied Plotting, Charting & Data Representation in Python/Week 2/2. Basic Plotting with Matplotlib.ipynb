# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline magic is not interactive
# %matplotlib notebook
plt.plot(3,2,'.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)

ax = fig.add_subplot(111)
ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img src = 'test.png'/>
# Out:
# <img src = 'test.png'/>

# %%
plt.figure()
plt.plot(3,2,'o')
#plt.gca() is getting the current axes
ax = plt.gca()
# setting the xlim =[0,6], ylim = [0,10]
ax.axis([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 10]

# %%
# could plot several points in a same figure
plt.figure()
plt.plot(1.5, 1.5, 'o')
plt.plot(2, 2, 'o')
plt.plot(2.5, 2.5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# we could get even further
# get the child objects that axes contain

ax = plt.gca()
ax.get_children()
# Out:
# ...
#  Text(0.5,1,''),
#  Text(0,1,''),
#  Text(1,1,''),
# ...
